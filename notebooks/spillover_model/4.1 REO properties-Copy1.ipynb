# %% [markdown]
# # Analysis of vacancy and foreclosures, transactions, sheriff's auctions, and armslength sales

# %%
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %matplotlib inline

path = '/'.join(os.getcwd().split('/')[:-1])
print(path)
# Out:
# /Volumes/Dropbox/largetransfer/luc/carter

# %%
tci = pd.read_csv(path+'/data/model_data/tci_1_0.csv', index_col = 0,parse_dates=['Date'])
tci = tci[['parcel','vacant','SPA_NAME','Date']]
# tci = pd.read_csv(path+'/data/model_data/tci_2_2.csv', parse_dates=['Date'], dtype={'Parcel ID':str})
# tci = pd.merge(tci, df[['NAME10','SPA_NAME']], how='left', right_index=True, left_on='parcel')
ppns = set(tci['parcel'])
dates = dict(zip(tci.parcel, tci.Date))
print(tci.shape)
# Out:
# (113132, 4)

# %% [markdown]
# ## Foreclosures

# %%
fc = pd.read_csv(path+'/data/clean_data/foreclosure_filings2.csv', parse_dates=[2])
fc = fc.sort_values('filedate').groupby('caseno').last()
fc = fc.rename(columns={'filedate':'date'}).reset_index()

fc.columns
# Out:
# Index([u'caseno', u'parcel', u'status', u'date', u'defendant',
#        u'parcel_address', u'dateid', u'case_title', u'plaintiff', u'FORE',
#        u'LATITUDE', u'LONGITUDE', u'zip_fore'],
#       dtype='object')

# %%
fc_parcel = set(fc.parcel)
tci['fc'] = tci.apply(lambda x: x.parcel in fc_parcel, axis=1)
pd.crosstab(tci.fc, tci.vacant)
# Out:
# vacant      0     1
# fc
# False   79154  3836
# True    23940  6202

# %%
sum(tci.vacant), sum(tci.fc)
# Out:
# (10038, 30142)

# %% [markdown]
# #### Has it been foreclosed before?
#
# So of the 30,142 parcels that have been foreclosed between 1/3/2006 and 11/6/2015, 6,202 are currently vacant, of the 10,038 total residential vacancies as measured by TCI. This means that 3,836 parcels were determined to be vacancy but never have been foreclosed.

# %%
fc_parcel = set(fc[fc.status=='Inactive'].parcel)
tci['fc'] = tci.apply(lambda x: x.parcel in fc_parcel, axis=1)
pd.crosstab(tci.fc, tci.vacant)
# Out:
# vacant      0     1
# fc
# False   79967  4135
# True    23127  5903

# %%
fc_parcel = set(fc[fc.status=='Active'].parcel)
tci['fc'] = tci.apply(lambda x: x.parcel in fc_parcel, axis=1)
pd.crosstab(tci.fc, tci.vacant)
# Out:
# vacant       0     1
# fc
# False   101689  9455
# True      1405   583

# %%
tem = pd.merge(fc[['parcel','status']].groupby('parcel').count(), tci[['parcel','vacant']], how='right', left_index=True, right_on='parcel').fillna(0)
tem = tem[['status','vacant']].groupby('status').agg([sum,len])
tem['percent'] = tem.vacant['sum']/tem.vacant['len']
tem.T
# Out:
# status                  0             1            2            3           4  \
# vacant  sum   3836.000000   4193.000000  1579.000000   330.000000   81.000000
#         len  82990.000000  22045.000000  6255.000000  1422.000000  326.000000
# percent          0.046222      0.190202     0.252438     0.232068    0.248466
#
# status               5          6      7
# vacant  sum  14.000000   4.000000  1.000
#         len  71.000000  15.000000  8.000
# percent       0.197183   0.266667  0.125

# %% [markdown]
# ## Sheriff's Auctions

# %%
sa = pd.read_csv(path+'/data/clean_data/sheriff_auction.csv', parse_dates=[2])#, encoding="ISO-8859-1")

# %%
reo = pd.read_csv(path+'/data/extra_data/reo.csv', encoding="utf-8")
reo = reo.groupby('GRANTEE1').last()

# %%
purchaser = sa.groupby('scaseno').last()
purchaser = purchaser.groupby('purchaser').count().sort_values('parcel',ascending=False)[['parcel']]

# %%
# purchaser = sa.groupby('scaseno').last().groupby('purchaser').count().sort_values('parcel',ascending=False)[['parcel']]
purchaser = purchaser.rename(columns={'parcel':'purchaser_count'})
sa = pd.merge(sa, purchaser, how='left', left_on='purchaser',right_index=True)
# sa = sa.sort_values('salesdt').groupby('parcel').last()
sa = sa.rename(columns={'salesdt':'date'})
# sa = sa[['date','plaintiff_count']]
# sa['type'] = 'sa'
# sa = sa.reset_index()
sa['purchaser_count'] = sa['purchaser_count'].fillna(0)
sa.columns
# Out:
# Index([u'parcel', u'address', u'date', u'saleno', u'sold_amt', u'appraisal',
#        u'minbid', u'scaseno', u'withdrawn', u'plaintiff', u'sdefend',
#        u'purchaser', u'paddress', u'rparty', u'raddress', u'attorney',
#        u'descript', u'location', u'defend_att', u'with', u'status', u'ssold',
#        u'SHF', u'LATITUDE', u'LONGITUDE', u'purchaser_count'],
#       dtype='object')

# %%
# al = pd.read_csv(path+'/data/clean_data/armslength.csv',dtype=str)
# al = al.drop_duplicates()

# months = dict(zip(['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC'],range(1,13)))

# def parse_date(x):
#     day = int(x[0:2])
#     month = months[x[2:5]]
#     year = int(x[5:])
#     return dt.datetime(year,month,day)

# al['date'] = al.mdate.apply(parse_date)
# # al = al[al.date < dt.datetime(2015,6,1)]

# al = al.rename(columns={'PROPERTY_NUMBER':'parcel'})
# al = al[['date','parcel']]
# al['type'] = 'al'
# al['plaintiff_count'] = 0

# %%
# t2 = pd.read_csv(path+'/data/clean_data/transfers.csv', parse_dates=['mdate'], dtype=str)

# %%
t = pd.read_csv(path+'/data/clean_data/transfers.csv', parse_dates=['mdate'], dtype=str)

t = t.rename(columns={'PROPERTY_NUMBER':'parcel','mdate':'date'})
t['type'] = 't'
t['REO'] = 0

# %%
t = pd.merge(t, reo, how='left',left_on='GRANTEE1', right_index=True)

# %%
t.loc[(t.DEED_TYPE.isin(['Sheriffs Deed',
 'Sheriffs Deed Ex'])),'shf'] = 1

# %%
reo
# Out:
#                                                                               stdgr1  \
# GRANTEE1
# #NAME?                                                    CENTEX  HOME  EQUITY  CORP
# AAMES CAPITAL CORP                                              AAMES  CAPITAL  CORP
# AAMES CAPITAL CORP. & AAMES FUNDING CORPORATION                 AAMES  CAPITAL  CORP
# AAMES CAPITAL CORPORATION                                       AAMES  CAPITAL  CORP
# AAMES FINANCIAL CORPORATION                                     AAMES  CAPITAL  CORP
# AAMES FUNDING CORPORATION                                       AAMES  CAPITAL  CORP
# AAMES FUNDING CORPORATION DBA AAMES HOME LOAN                   AAMES  CAPITAL  CORP
# AAMES FUNDING CORPORATION, DBA AAMES HOME LOAN                  AAMES  CAPITAL  CORP
# AAMES HOME LOAN                                                 AAMES  CAPITAL  CORP
# ABM AMRO MORTGAGE GROUP                                                ABN AMRO BANK
# ABN  AMRO MORTGAGE  GROUP  INC.                                        ABN AMRO BANK
# ABN  AMRO MORTGAGE GROUP                                               ABN AMRO BANK
# ABN  AMRO MORTGAGE GROUP, INC.                                         ABN AMRO BANK
# ABN  AMRO MORTGAGE INC                                                 ABN AMRO BANK
# ABN AMBRO Mortgage Group, Inc.                                         ABN AMRO BANK
# ABN AMR MORTGAGE GROUP, INC.                                           ABN AMRO BANK
# ABN AMRO                                                               ABN AMRO BANK
# ABN AMRO  MORTGAGE GROUP, INC.                                         ABN AMRO BANK
# ABN AMRO BANK                                                          ABN AMRO BANK
# ABN AMRO MARTGAGE GROUP, INC                                           ABN AMRO BANK
# ABN AMRO MORT GROUP INC                                                ABN AMRO BANK
# ABN AMRO MORTGAGE CORPORATION, INC.                                    ABN AMRO BANK
# ABN AMRO MORTGAGE GROUP                                                ABN AMRO BANK
# ABN AMRO MORTGAGE GROUP  INC.                                          ABN AMRO BANK
# ABN AMRO MORTGAGE GROUP INC                                            ABN AMRO BANK
# ABN AMRO MORTGAGE GROUP INC.                                           ABN AMRO BANK
# ABN AMRO MORTGAGE GROUP, INC                                           ABN AMRO BANK
# ABN AMRO MORTGAGE GROUP, INC.                                          ABN AMRO BANK
# ABN AMRO Mortgage                                                      ABN AMRO BANK
# ABN AMRO Mortgage Group                                                ABN AMRO BANK
# ...                                                                              ...
# Wells Fargo Minesota, Na                                                 WELLS FARGO
# Wells Fargo Minnesota National Association                               WELLS FARGO
# Wells Fargo Minnesota, as Trustee                                        WELLS FARGO
# Wells Fargo Natioanl Bank Minnesota -Tr.                                 WELLS FARGO
# Wells Fargo bank                                                         WELLS FARGO
# Wells fargo Bank Minnesota, NA, Trustee                                  WELLS FARGO
# Wells fargo Minnesota, as Trustee                                        WELLS FARGO
# Wells fargo Trustee                                                      WELLS FARGO
# Wells fargo bank Minn trustee                                            WELLS FARGO
# Wels Fargo Bank Minnesota                                                WELLS FARGO
# Wilimington Trs Co                                                  WILMINGTON TRUST
# Willimington Trs Co                                                 WILMINGTON TRUST
# Wilmington Trs Co Trs                                               WILMINGTON TRUST
# Wm Specialty Mort Llc,                                WM SPECIALTY MORTGAGE, LLC ETC
# Wm Specialty Mortgage LLC                             WM SPECIALTY MORTGAGE, LLC ETC
# Wm Specialty Mtg Llc                                  WM SPECIALTY MORTGAGE, LLC ETC
# Wmc Mort Corp                                                      WMC MORTGAGE CORP
# Wmc Mort Corp.                                                     WMC MORTGAGE CORP
# Wmc Mortgage Corp                                                  WMC MORTGAGE CORP
# World Savings Bank FSB                                            WORLD SAVINGS BANK
# World Savings Bank, FSB                                           WORLD SAVINGS BANK
# \H.U.D                                           DEPARTMENT OF HOUSING AND URBAN DEV
# keybank National Assoc.                               KEY  BANK NATIONAL ASSCOIATION
# mANUFACTUREERS & TRADERS TRUST                                           M & T  BANK
# national City Bank                                                NATIONAL CITY BANK
# sec of h.u.d.                                    DEPARTMENT OF HOUSING AND URBAN DEV
# sec of housing & urban dev.                      DEPARTMENT OF HOUSING AND URBAN DEV
# the Bank of NewYork                                      THE BANK OF NEW YORK, TRUST
# us Bank National                                                           U S  BANK
# wm Specialty Mortgage llc                             WM SPECIALTY MORTGAGE, LLC ETC
#
#                                                               finalgr1
# GRANTEE1
# #NAME?                                           FINANCIAL INSTITUTION
# AAMES CAPITAL CORP                               FINANCIAL INSTITUTION
# AAMES CAPITAL CORP. & AAMES FUNDING CORPORATION  FINANCIAL INSTITUTION
# AAMES CAPITAL CORPORATION                        FINANCIAL INSTITUTION
# AAMES FINANCIAL CORPORATION                      FINANCIAL INSTITUTION
# AAMES FUNDING CORPORATION                        FINANCIAL INSTITUTION
# AAMES FUNDING CORPORATION DBA AAMES HOME LOAN    FINANCIAL INSTITUTION
# AAMES FUNDING CORPORATION, DBA AAMES HOME LOAN   FINANCIAL INSTITUTION
# AAMES HOME LOAN                                  FINANCIAL INSTITUTION
# ABM AMRO MORTGAGE GROUP                                 NONLOCAL BANKS
# ABN  AMRO MORTGAGE  GROUP  INC.                         NONLOCAL BANKS
# ABN  AMRO MORTGAGE GROUP                                NONLOCAL BANKS
# ABN  AMRO MORTGAGE GROUP, INC.                          NONLOCAL BANKS
# ABN  AMRO MORTGAGE INC                                  NONLOCAL BANKS
# ABN AMBRO Mortgage Group, Inc.                          NONLOCAL BANKS
# ABN AMR MORTGAGE GROUP, INC.                            NONLOCAL BANKS
# ABN AMRO                                                NONLOCAL BANKS
# ABN AMRO  MORTGAGE GROUP, INC.                          NONLOCAL BANKS
# ABN AMRO BANK                                           NONLOCAL BANKS
# ABN AMRO MARTGAGE GROUP, INC                            NONLOCAL BANKS
# ABN AMRO MORT GROUP INC                                 NONLOCAL BANKS
# ABN AMRO MORTGAGE CORPORATION, INC.                     NONLOCAL BANKS
# ABN AMRO MORTGAGE GROUP                                 NONLOCAL BANKS
# ABN AMRO MORTGAGE GROUP  INC.                           NONLOCAL BANKS
# ABN AMRO MORTGAGE GROUP INC                             NONLOCAL BANKS
# ABN AMRO MORTGAGE GROUP INC.                            NONLOCAL BANKS
# ABN AMRO MORTGAGE GROUP, INC                            NONLOCAL BANKS
# ABN AMRO MORTGAGE GROUP, INC.                           NONLOCAL BANKS
# ABN AMRO Mortgage                                       NONLOCAL BANKS
# ABN AMRO Mortgage Group                                 NONLOCAL BANKS
# ...                                                                ...
# Wells Fargo Minesota, Na                                NONLOCAL BANKS
# Wells Fargo Minnesota National Association              NONLOCAL BANKS
# Wells Fargo Minnesota, as Trustee                       NONLOCAL BANKS
# Wells Fargo Natioanl Bank Minnesota -Tr.                NONLOCAL BANKS
# Wells Fargo bank                                        NONLOCAL BANKS
# Wells fargo Bank Minnesota, NA, Trustee                 NONLOCAL BANKS
# Wells fargo Minnesota, as Trustee                       NONLOCAL BANKS
# Wells fargo Trustee                                     NONLOCAL BANKS
# Wells fargo bank Minn trustee                           NONLOCAL BANKS
# Wels Fargo Bank Minnesota                               NONLOCAL BANKS
# Wilimington Trs Co                                      NONLOCAL BANKS
# Willimington Trs Co                                     NONLOCAL BANKS
# Wilmington Trs Co Trs                                   NONLOCAL BANKS
# Wm Specialty Mort Llc,                           FINANCIAL INSTITUTION
# Wm Specialty Mortgage LLC                        FINANCIAL INSTITUTION
# Wm Specialty Mtg Llc                             FINANCIAL INSTITUTION
# Wmc Mort Corp                                    FINANCIAL INSTITUTION
# Wmc Mort Corp.                                   FINANCIAL INSTITUTION
# Wmc Mortgage Corp                                FINANCIAL INSTITUTION
# World Savings Bank FSB                                  NONLOCAL BANKS
# World Savings Bank, FSB                                 NONLOCAL BANKS
# \H.U.D                                                             GSE
# keybank National Assoc.                                    LOCAL BANKS
# mANUFACTUREERS & TRADERS TRUST                          NONLOCAL BANKS
# national City Bank                                         LOCAL BANKS
# sec of h.u.d.                                                      GSE
# sec of housing & urban dev.                                        GSE
# the Bank of NewYork                                     NONLOCAL BANKS
# us Bank National                                           LOCAL BANKS
# wm Specialty Mortgage llc                        FINANCIAL INSTITUTION
#
# [6365 rows x 2 columns]

# %%
temp = tci[tci.parcel.isin(t[(t.REO==1)&(t.date > dt.datetime(2013,1,1))].parcel)]
sum(temp.vacant), len(temp)

# %%
fc2 = fc[['date','parcel']]
fc2['type'] = 'fc'
fc2['REO'] = 0
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
sa2 = sa[['date','parcel','sold_amt']]
sa2['REO'] = 0
sa2['type'] = 'sa'
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
df = fc2.append(sa2.loc[sa2.sold_amt.notnull(),['date','REO','parcel','type']]).append(t[['date','parcel','type','REO','DEED_TYPE','GRANTEE1']])
df = df.sort_values('date')
df = df.loc[df.apply(lambda x: x.date < dates[x.parcel], axis=1)]

# %%
last = df.groupby('parcel').last()
sub = last[(last['type'] == 't') & (last['DEED_TYPE'].isin(['Sheriffs Deed',
 'Sheriffs Deed Ex'])) & (last['REO'])]#&(last['plaintiff_count']>-1)]

# %%
test = set(sub.index)
sum(tci[tci.parcel.isin(test)].vacant), len(tci[tci.parcel.isin(test)].vacant)
# Out:
# (546, 1203)

# %%
tci.loc[tci.parcel.isin(test),['SPA_NAME','vacant']].groupby('SPA_NAME').agg([sum,len])
# Out:
#                         vacant
#                            sum  len
# SPA_NAME
# Bellaire-Puritas            17   46
# Broadway-Slavic Village     43   73
# Brooklyn Centre             11   27
# Buckeye-Shaker Square       18   43
# Buckeye-Woodhill            10   18
# Central                      4   10
# Clark-Fulton                 6   22
# Collinwood-Nottingham       28   58
# Cudell                      16   32
# Detroit Shoreway             7   23
# Edgewater                    2    7
# Euclid-Green                 7   19
# Fairfax                      8   14
# Glenville                   65   95
# Goodrich-Kirtland Pk         6    8
# Hough                        7   18
# Jefferson                   28   68
# Kamm's                      20   53
# Kinsman                     12   20
# Lee-Harvard                 26   63
# Lee-Seville                  8   23
# Mount Pleasant              44   84
# North Shore Collinwood      24   55
# Ohio City                    3    8
# Old Brooklyn                36  102
# St.Clair-Superior            6   13
# Stockyards                  14   31
# Tremont                      2    9
# Union-Miles                 37   86
# University                   1    3
# West Boulevard              30   72

# %%
import re

def find_REO(s):
    if isinstance(s,str) or isinstance(s,unicode):
        s = s.lower()
        if re.search("llc", s):
            return True
        if re.search("bank", s):
            return True
        if re.search("mortg", s):
            return True
        if re.search("mort.", s):
            return True
        if re.search("comp", s):
            return True
        if re.search("corp", s):
            return True
        if re.search("fannie", s):
            return True
        if re.search("housing", s):
            return True
        if re.search("sec.", s):
            return True
        if re.search("loan", s):
            return True
        return False
    else:
        return False

# %%
sum(sa['REO'])
# Out:
# 22976

# %%
sa.groupby('purchaser').count().sort_values('date',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b545ff79b715> in <module>()
# ----> 1 sa.groupby('purchaser').count().sort_values('date',ascending=False)
#
# NameError: name 'sa' is not defined

# %%
sa['REO'] = sa.purchaser.apply(find_REO)

# %%
t['REO'] = t.GRANTEE1.apply(find_REO)

# %%
t[(t.shf==1)&t.REO]
# Out:
#        TRANSFER_TO_ID   WHS_ID TRANSFER_HISTORY_ID TRANSFER_ORDER PARCEL_ID  \
# 102         591491638  4282084           676448184              4    102024
# 157        1687613006  4286307           972164435             15    104007
# 169        2040389458  4286316           871525777             11    104016
# 230         849225706  4288480           838247536              3    105025
# 270        1831971867  4290658           814858079              8    106025
# 309        1088011691  4292833           249970982              4    107018
# 313           9673909  4292835          1558894809             10    107020
# 322         938538843  4292845           728023415              9    107030
# 324        1442093915  4292845           926113198             11    107030
# 327        1499158716  4292846          1636589576             13    107031
# 329         966105061  4292846          1995885836             15    107031
# 334         917237912  4292848           616919721              7    107033
# 344        1042775264  4292855           479053958              7    107040
# 354        1339866238  4292860           918929470              5    107045
# 364         970073900  4295011           389295533              6    107053
# 382        1416204623  4295020          1601389224              5    107063
# 391        1778123502  4295026           894212914              9    107069
# 393         934105246  4295028          1199672250              6    107071
# 404        1146760032  4295032            70433002              3    107075
# 409         477374994  4295033           747873037              7    107076
# 412        1524737439  4295036          1072384014              4    107079
# 416        2141904059  4295038          1099970808              3    107081
# 429         850891483  4295039          1397140023             16    107084
# 459         702213556  4297236           107805308              6    108007
# 476        1353151990  4299393          1392071221              9    108033
# 481        1737682549  4299394           808053808              8    108034
# 483         880837260  4299406           847052470              5    108046
# 492         938203238  4299409          1301084643              7    108049
# 494        1705598658  4299410          1053273182              5    108050
# 498         594510380  4299412          1165297988              9    108052
# ...               ...      ...                 ...            ...       ...
# 210826  SNEED, DONNELL BOBO & BOLAR, FARICA 2006-11-16      36667.0 ...
# 210830                    Jones , Pearlenea 2014-02-07      22725.0 ...
# 210833         Stephens General C & Levolia 2008-04-25          0.0 ...
# 210838                    Hayes, Dewayne R. 2007-08-03      36667.0 ...
# 210842           Green, Andrea K. & MICHAEL 2009-02-19      90000.0 ...
# 210844                      Seymour Flora H 2015-02-10          0.0 ...
# 210850                     Darling, Preston 2006-11-15      96667.0 ...
# 210853                     Williams, Julius 2000-03-06          0.0 ...
# 210858                      Lorenzi, Lisa M 2009-12-09      16667.0 ...
# 210863                     Mixon, Sherri L. 2003-02-28      50000.0 ...
#
#        GRANTOR_IS_RELATIVE TRADE TRANSFER_TYPE_DESCR SALES_SOURCE_DESCR  \
# 102                    0.0   0.0    Change Ownership                NaN
# 157                    0.0   0.0    Change Ownership                NaN
# 169                    0.0   0.0    Change Ownership                NaN
# 230                    0.0   0.0    Change Ownership                NaN
# 270                    0.0   0.0    Change Ownership                NaN
# 309                    0.0   0.0    Change Ownership                NaN
# 313                    0.0   0.0    Change Ownership                NaN
# 322                    0.0   0.0    Change Ownership                NaN
# 324                    0.0   0.0    Change Ownership                NaN
# 327                    0.0   0.0    Change Ownership                NaN
# 329                    0.0   0.0    Change Ownership                NaN
# 334                    0.0   0.0    Change Ownership                NaN
# 344                    0.0   0.0    Change Ownership                NaN
# 354                    0.0   0.0    Change Ownership                NaN
# 364                    0.0   0.0    Change Ownership                NaN
# 382                    0.0   0.0    Change Ownership                NaN
# 391                    0.0   0.0    Change Ownership                NaN
# 393                    0.0   0.0    Change Ownership                NaN
# 404                    0.0   0.0    Change Ownership                NaN
# 409                    0.0   0.0    Change Ownership                NaN
# 412                    0.0   0.0    Change Ownership                NaN
# 416                    0.0   0.0    Change Ownership                NaN
# 429                    0.0   0.0    Change Ownership                NaN
# 459                    0.0   0.0    Change Ownership              Agent
# 476                    0.0   0.0    Change Ownership                NaN
# 481                    0.0   0.0    Change Ownership                NaN
# 483                    0.0   0.0    Change Ownership                NaN
# 492                    0.0   0.0    Change Ownership                NaN
# 494                    0.0   0.0    Change Ownership                NaN
# 498                    0.0   0.0    Change Ownership                NaN
# ...                    ...   ...                 ...                ...
# 210525                 0.0   0.0    Change Ownership                NaN
# 210527                 0.0   0.0    Change Ownership                NaN
# 210548                 0.0   0.0    Change Ownership                NaN
# 210550                 0.0   0.0    Change Ownership                NaN
# 210553                 0.0   0.0    Change Ownership                NaN
# 210557                 0.0   0.0    Change Ownership                NaN
# 210572                 0.0   0.0    Change Ownership                NaN
# 210585                 0.0   0.0    Change Ownership                NaN
# 210587                 0.0   0.0    Change Ownership                NaN
# 210589                 0.0   0.0    Change Ownership                NaN
# 210624                 0.0   0.0    Change Ownership                NaN
# 210631                 0.0   0.0    Change Ownership                NaN
# 210643                 0.0   0.0    Change Ownership                NaN
# 210685                 0.0   0.0    Change Ownership                NaN
# 210631                            NaN                  NaN   07NOV2014    t
# 210643                            NaN                  NaN   07NOV2014    t
# 210685                            NaN                  NaN   07NOV2014    t
# 210694                            NaN                  NaN   07NOV2014    t
# 210721                            NaN                  NaN   07NOV2014    t
# 210730  USA / State/ Political Subdiv                  NaN   07NOV2014    t
# 210767                            NaN                  NaN   07NOV2014    t
# 210799                            NaN                  NaN   07NOV2014    t
# 210816                            NaN                  NaN   07NOV2014    t
# 210826                            NaN                  NaN   07NOV2014    t
# 210830                            NaN                  NaN   07NOV2014    t
# 210833                            NaN                  NaN   07NOV2014    t
# 210838                            NaN                  NaN   07NOV2014    t
# 210842                            NaN                  NaN   07NOV2014    t
# 210844  USA / State/ Political Subdiv                  NaN   13FEB2015    t
# 210850                            NaN                  NaN   07NOV2014    t
# 210853                            NaN                  NaN   07NOV2014    t
# 210858                            NaN                  NaN   07NOV2014    t
# 210863                            NaN                  NaN   07NOV2014    t
#
#          REO shf
# 102     True   1
# 157     True   1
# 169     True   1
# 230     True   1
# 270     True   1
# 309     True   1
# 313     True   1
# 322     True   1
# 324     True   1
# 327     True   1
# 329     True   1
# 334     True   1
# 344     True   1
# 354     True   1
# 364     True   1
# 382     True   1
# 391     True   1
# 393     True   1
# 404     True   1
# 409     True   1
# 412     True   1
# 416     True   1
# 429     True   1
# 459     True   1
# 476     True   1
# 481     True   1
# 483     True   1
# 492     True   1
# 494     True   1
# 498     True   1
# ...      ...  ..
# 210525  True   1
# 210527  True   1
# 210548  True   1
# 210550  True   1
# 210553  True   1
# 210557  True   1
# 210572  True   1
# 210585  True   1
# 210587  True   1
# 210589  True   1
# 210624  True   1
# 210631  True   1
# 210643  True   1
# 210685  True   1
# 210694  True   1
# 210721  True   1
# 210730  True   1
# 210767  True   1
# 210799  True   1
# 210816  True   1
# 210826  True   1
# 210830  True   1
# 210833  True   1
# 210838  True   1
# 210842  True   1
# 210844  True   1
# 210850  True   1
# 210853  True   1
# 210858  True   1
# 210863  True   1
#
# [23292 rows x 63 columns]

# %%
t.shape
# Out:
# (210880, 62)

# %%
len(tci[tci.parcel.isin(df[(df.date>dt.datetime(2015,1,1)) & (df.DEED_TYPE.isin(['Sheriffs Deed',
 'Sheriffs Deed Ex']))].parcel)].vacant)
# Out:
# 498

# %%
df.groupby('parcel').last().groupby('type').()
# Out:
#       DEED_TYPE  GRANTEE1    REO   date
# type
# fc         7635      7635  11337  11337
# sa          754       754   1074   1074
# t         68664     68664  68664  68664

# %%
sum(t.REO)
# Out:
# 48993

# %%
find_REO(sa.purchaser.iloc[6])
# Out:
# True

# %%
s = sa.groupby('scaseno').last()

# %%
ts = tci[tci.parcel.isin(s[(s.REO) & (s.date > dt.datetime(2011,1,1))].parcel)]
sum(ts.vacant), len(ts)
# Out:
# (1289, 5716)

# %%
spas_sa = tci[tci.parcel.isin(test)][['SPA_NAME','vacant']].groupby('SPA_NAME').agg([sum,len])
spas_sa['percent'] = spas_sa.vacant['sum']*1.0/spas_sa.vacant['len']
print(spas_sa.sort_values('percent'))

# %%
for i in spas_sa.index:
    a = sa[sa.parcel.isin(test.intersection(tci[tci.SPA_NAME==i].parcel))]
    spas_sa.loc[spas_sa.index==i,'median_sa'] = a.sort_values('date')['date'].iloc[round(len(a)/2)]
#     print(i,a.sort_values('date')['date'].iloc[round(len(a)/2)])
#     print(np.median(sa[sa.parcel.isin(test.intersection(tci[tci.SPA_NAME==i].parcel))].date))

# %%
spas_sa

# %%
tci[tci.parcel.isin(set(fc.parcel))][['SPA_NAME','vacant']].groupby('SPA_NAME').agg([sum,len])

# %%
len(tci.loc[tci.vacant==1,'parcel'][tci.loc[tci.vacant==1,'parcel'].isin(set(sa.parcel))])

# %%
sum(tci['vacant']), len(tci)

# %%
sum(tci[tci.parcel.isin(sub)].vacant), len(tci[tci.parcel.isin(sub)].vacant)

# %%
last = df.groupby('parcel').last()
sub = set(last[last['type'] == 'sa'].index)

# %%
second_last = df.groupby('parcel').nth(-2)
sub2 = set(second_last[second_last['type']=='fc'].index)

# %%
len(sub.intersection(sub2)), len(sub), len(sub2)

# %%
fc_to_sa = sub.intersection(sub2)

# %%
sum(tci[tci.parcel.isin(fc_to_sa)].vacant), len(tci[tci.parcel.isin(fc_to_sa)].vacant)

# %%
df[df.parcel=='137-25-057']

# %%
a = second_last[second_last.index.isin(sub)]

# %%
pitt_vacant = set(second_last[second_last.index.isin(sub)].index)

# %%
pv = pd.read_csv(path+'/data/clean_data/postal_vacancy.csv', parse_dates=3, index_col=0)
pv.date = pv.date.apply(lambda x: dt.datetime(int(x[0:4]),int(x[5:7]),int(x[8:10])))
pv = pv.sort_values('date',ascending=False)
pv = pv.loc[pv.apply(lambda x: x.date < dates[x.PARCEL], axis=1)]

# %%
pv = pv[pv.vindall=='Y']
pv_copy = pv.copy().groupby('PARCEL').count().reset_index()

pv_copy['pv_count'] = pv_copy.apply(lambda x: \
        len(pv[(pv.PARCEL == x.PARCEL) & (pv.date > dates[x.PARCEL]-pd.DateOffset(years=2))]), axis=1)

# %%
pv2 = pv.groupby('PARCEL').last()

# %%
tci[tci.parcel.isin(pv2[pv2.vindall=='Y'].index)].groupby('vacant').count()

# %%
sns.distplot(df2[df2.vacant==1].date,bins=np.linspace(0,30,30));
sns.distplot(df2[df2.vacant==0].date,bins=np.linspace(0,30,30));

# %%
df2 = pd.merge(df.groupby('parcel').last(), tci[['vacant','ppn']], how='left',left_index=True, right_on='ppn')

# %%
df2[['type','vacant']].groupby('type').agg([sum,len])

# %%
d = df2[df2['type']=='fc']
d['year'] = d.date.apply(lambda x: x.year)

# %%
d[['year','vacant']].groupby('year').agg([sum,len])

# %%
plt.plot(fc.set_index('date').groupby(['type']).resample('m', 'count'))

# %%
t = tci[tci.ppn.isin(fc[fc.date > dt.datetime(2015,3,1)].parcel)].vacant

# %%
sum(t),len(t)

# %%
fc['year'] = fc['date']
