# %%
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import pandas as pd
import numpy as np
import os
import re

# %matplotlib inline

path = '/'.join(os.getcwd().split('/')[:-2])
print(path)
# Out:
# /Volumes/Dropbox/largetransfer/luc/carter
# //anaconda/envs/data_sci/lib/python3.4/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
# import data
# Out:
# //anaconda/envs/data_sci/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (17,18,20,23,25,27,39,45,46,48,55,68,69,70,86,87,92) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# z_standcons2.1-2.10 + z_final2.1-2.10 + z_ngrantee1-10

cols = ['z_ngrantee.1','z_ngrantee.2','z_ngrantee.3','z_ngrantee.4','z_ngrantee.5',\
        'z_ngrantee.6','z_ngrantee.7','z_ngrantee.8','z_ngrantee.9','z_ngrantee.10',\
        'z_final2.1','z_final2.2','z_final2.3','z_final2.4','z_final2.5','z_final2.6',\
        'z_final2.7','z_final2.8','z_final2.9','z_final2.10']

# %%
df.shape
# Out:
# (42545, 576)

# %%
df = pd.read_csv(path+'/data/extra_data/20130901_final_dataset_restruct_1.csv')
df2 = df[['z_ngrantee.1','z_final2.1']]
for num in range(2,11):
    df2 = df2.append(df[['z_ngrantee.'+str(num),'z_final2.'+str(num)]]\
                     .rename(columns={'z_ngrantee.'+str(num):'z_ngrantee.1', 'z_final2.'+str(num):'z_final2.1'})\
                     ,ignore_index=True)

# %%
# df2 = df[['z_ngrantee.1','z_final2.1']]
# for num in range(2,11):
#     df2 = df2.append(df[['z_ngrantee.'+str(num),'z_final2.'+str(num)]]\
#                      .rename(columns={'z_ngrantee.'+str(num):'z_ngrantee.1', 'z_final2.'+str(num):'z_final2.1'})\
#                      ,ignore_index=True)

# %%
df3 = pd.read_excel(path+'/data/extra_data/STANDARDIZED.xls')
df3[['z_ngrantee','z_final']].rename(columns={'z_ngrantee':'grantee','z_final':'cat'})\
    .append(df3[['z_std','z_final']].rename(columns={'z_std':'grantee','z_final':'cat'}))
# Out:
#                                                  grantee  \
# 0                  ALFIERI BROTHERS MATERIALS SUPPLY CO.
# 1        CLEVELAND HOUSING NETWORK LIMITED PARTNERSHI...
# 2                                  Griffith, Marshall A.
# 3                               KESOSINGHARATH , SOUTHEN
# 4                                ROBERTSON, FREDERICK J.
# 5                       A NEW BEGINNING SOBER LIVING INC
# 6                                A-1 DREAM BUILDERS LLC.
# 7                                    AEON FINANCIAL, LLC
# 8                                        ALLEN, LAVORA L
# 9                                    ANS DEVELOPMENT LLC
# 10                          BADEA, ALEXANDRU & ECATERINA
# 11                                       BENDER, BARBARA
# 12                                    BENDER, BARBARA H.
# 13                                       BREWER, VERA D.
# 14                                  BROOKS, ROBERT L. JR
# ...

# %%
df[cols]
# Out:
#                                          z_ngrantee.1  \
# 0                                      BORN, JARED M.
# 1                                       MAHER, TODD E
# 2                             ZACHARIAS, LEROY M. JR.
# 3                                    HARRY, RUSSELL J
# 4                                        HANNA,JOSEPH
# 5                             PERDUE, DALE & JANET L.
# 6                              Porrello Jr, Raymond A
# 7                                     Bishop, Terence
# 8                                       REVINOV, EMIL
# 9                   PROGRESSIVE CONSULTING GROUP, INC
# 10                                  HAMMOND, ROBERT G
# 11                   STONE INVESTMENT PROPERTIES, LLC
# 12                             DELISLE, GINA MARIE A.
# 13                                    KRAINESS, NAOMI
# 14                                 THOMPSON, BRIAN L.
# 15                                     JENKO, RIKK E.
# ...
